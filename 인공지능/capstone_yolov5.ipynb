# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %mkdir /content/test_start

# %%
# %cd /content/test_start

# %%
# !unzip -qq "/content/drive/MyDrive/deu2/data_f/dog_cat.zip"

# %%
from glob import glob

train_list = glob('/content/test_start/train/images/*.jpg')
test_list = glob('/content/test_start/test/images/*.jpg')
valid_list = glob('/content/test_start/valid/images/*.jpg')

len(train_list),len(valid_list),len(test_list)

# %%
with open('/content/test_start/train/train.txt', 'w') as f:
    f.write('\n'.join(train_list)+'\n')

with open('/content/test_start/test/test.txt', 'w') as f:
    f.write('\n'.join(train_list)+'\n')

with open('/content/test_start/valid/valid.txt', 'w') as f:
    f.write('\n'.join(train_list)+'\n')

# !ls /content/test_start/train/

# %%
# %cd /content/drive/MyDrive/deu2/yolo/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --batch 128 --img 416 --epochs 300 --data /content/test_start/data.yaml --cfg /content/drive/MyDrive/deu2/yolo/yolov5/models/yolov5s.yaml --weights '' --name cat_dog_300 --cache

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

model = YOLO('/content/drive/MyDrive/deu2/4월_프로젝트/ultralytics/runs/detect/cat_dog_3003/weights/best.pt')

result = model("/content/drive/MyDrive/deu2/yolo/a4.jpg")[0].plot()
pil_image=Image.fromarray(result[:, :, ::-1])
pil_image.show()
