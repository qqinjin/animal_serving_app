# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics

# %%
# !pip install PyYAML

# %%
# %mkdir /content/test_start

# %%
# %cd /content/test_start

# %%
# !unzip -qq "/content/drive/MyDrive/deu2/data_f/dog_cat.zip"

# %%
import ultralytics

ultralytics.checks()

# %%
# %cd /content/drive/MyDrive/deu2/4월_프로젝트/ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')

# %%
print(type(model.names), len(model.names))

print(model.names)

# %%
model.train(data = '/content/test_start/data.yaml', epochs = 300 , patience = 30, batch = 128, imgsz = 416, name = 'cat_dog_300' )
